# %%
import pandas as pd

# Membaca file Excel
df = pd.read_excel(r'D:\MSIB Mari Belajar\Project Capstone\instagram dataset\Instagram_dataset_per post tag maribelajar.xlsx')

# %%
# Menggabungkan kolom firstComment dan latestComments menjadi satu kolom komentar
df['komentar'] = df['firstComment'].fillna('') + ' ' + df['latestComments/0/text'].fillna('') + ' ' + df['latestComments/1/text'].fillna('') + ' ' + df['latestComments/2/text'].fillna('') + ' ' + df['latestComments/3/text'].fillna('') + ' ' + df['latestComments/4/text'].fillna('') + ' ' + df['latestComments/5/text'].fillna('') + ' ' + df['latestComments/6/text'].fillna('') + ' ' + df['latestComments/7/text'].fillna('') + ' ' + df['latestComments/8/text'].fillna('') + ' ' + df['latestComments/9/text'].fillna('')

# %%
df['komentar']
# Out:
# 0
# 1
# 2
# 3
# 4
#                              ...
# 172
# 173      Mangsteup wii Keren bgt!!! Semoga sukses sel...
# 174
# 175    Wow data Wow data yok semangat Wiii mantap nga...
# 176      woohoo akhirnya selesai yaa Wohooo Uuuuuuuuw...
# Name: komentar, Length: 177, dtype: object

# %%
df.dropna(subset=['komentar'], inplace=True)

# %%
df['komentar']
# Out:
# 0
# 1
# 2
# 3
# 4
#                              ...
# 172
# 173      Mangsteup wii Keren bgt!!! Semoga sukses sel...
# 174
# 175    Wow data Wow data yok semangat Wiii mantap nga...
# 176      woohoo akhirnya selesai yaa Wohooo Uuuuuuuuw...
# Name: komentar, Length: 177, dtype: object

# %%
pd.set_option('display.max_rows', None)  # Menampilkan semua baris
print(df['komentar'])
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7      KEREN!! SEMANGAT INTANNNN‍♀️ KEREN!! SEMANGAT ...
# 8      wah congrats ya nok, selamat menempuh SI semog...
# 9      info pengumuman hasil seleksi min info pengumu...
# 10     Cemunguuut Cemunguuut Keyennnn banget ❤‍ Waaaa...
# 11     wah sipaling merdeka xixixi wah sipaling merde...
# 12       Kelas betulll @khai.ihsan suttttt @uci.wln  ...
# 13
# 14       Keren gini madame  Semangattt lah ga jadi ng...
# 15     Semangattt faraa Semangattt faraa Ampunn suhuu...
# 16
# 17            Mntaplah Mntaplah Semnagat koncku✊
# 18
# 19
# 20
# 21
# 22
# 23     Jasa Desain CV dan Surat Lamaran Hanya 15K ❤️ ...
# 24
# 25
# 26
# 27     Sukses Satria Sukses Satria oo pantes minta fo...
# 28     keren kak keren kak inpo magang merdeka kak Ma...
# 29       ya Allah cantike seee masyaAllah mantapp jol...
# 30
# 31
# 32
# 33
# 34
# 35
# 36
# 37     sekolah anda kok dulu nggk mau yah @mlna_ap @a...
# 38
# 39     looting teroz looting teroz Yg di belakang sia...
# ...

# %%
df.to_excel('nama_file.xlsx', index=False)
